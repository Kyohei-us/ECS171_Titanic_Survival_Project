# %%
import pandas as pd
import numpy as np
import random as rnd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
titanic = pd.read_csv('./Data/train.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Understanding each column
# PassengerId - Unique ID for each passenger  <br>
# Survived - Survival (0 = No; 1 = Yes)   <br>
# Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)   <br>
# Name - Passenger Name   <br>
# Sex - Passenger Sex   <br>
# Age - Passenger Age   <br>
# SibSp - Number of Siblings/Spouses Aboard   <br>
# Parch - Number of Parents/Children Aboard   <br>
# ticket - Ticket Number   <br>
# Fare - Passenger Fare   <br>
# Cabin - Cabin number    <br>
# embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)   <br>

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Filling null data

# %%
# Finding missing data
miss_total = titanic.isnull().sum().sort_values(ascending=False)
percentage = miss_total/891 
percent_2 = (round(percentage, 3)).sort_values(ascending=False)
miss_total = pd.concat([miss_total, percent_2], axis=1, keys=['# of Null', 'Percentage'])
miss_total
# Out:
#              # of Null  Percentage
# Cabin              687       0.771
# Age                177       0.199
# Embarked             2       0.002
# PassengerId          0       0.000
# Survived             0       0.000
# Pclass               0       0.000
# Name                 0       0.000
# Sex                  0       0.000
# SibSp                0       0.000
# Parch                0       0.000
# Ticket               0       0.000
# Fare                 0       0.000

# %%
# drop Cabin column since it has huge amount of missing data, and it does not affect suvival (TODO: discuss this? Is there more about this attribute?)
titanic = titanic.drop(['Cabin'], axis=1)
# titanic.Cabin.unique()

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Age'].plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.title('Age disdribution before filling missing values')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
titanic['Age'].mean()
# Out:
# 29.69911764705882

# %%
# Replace missing age by average(Age)
titanic['Age']=titanic['Age'].fillna(titanic['Age'].mean())
miss_total = titanic.isnull().sum().sort_values(ascending=False)
miss_total
# Out:
# Embarked       2
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %%
titanic['Age'].plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.title('Age disdribution after filling missing values')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
# Finally, the two missing value of embarked 
titanic['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
# replace missing value with the most frequent one: S
titanic['Embarked'] = titanic['Embarked'].fillna('S')

# %%
# Now no missing values!
miss_total = titanic.isnull().sum().sort_values(ascending=False)
miss_total
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# # Encoding

# %%
# Male=0, Female=1
titanic.loc[titanic['Sex']=='male','Sex']= 0
titanic.loc[titanic['Sex']=='female','Sex']= 1
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   0  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.000000      1
# 2                               Heikkinen, Miss. Laina   1  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.000000      1
# 4                             Allen, Mr. William Henry   0  35.000000      0
# ...

# %%
titanic['Ticket'].describe()
# Out:
# count          891
# unique         681
# top       CA. 2343
# freq             7
# Name: Ticket, dtype: object

# %%
# Drop Ticket column
titanic = titanic.drop(['Ticket'], axis=1)

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
# encode the Embarked column
titanic.loc[titanic['Embarked']=='S','Embarked']=0
titanic.loc[titanic['Embarked']=='C','Embarked']=1
titanic.loc[titanic['Embarked']=='Q','Embarked']=2
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   0  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.000000      1
# 2                               Heikkinen, Miss. Laina   1  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.000000      1
# 4                             Allen, Mr. William Henry   0  35.000000      0
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
# convert object types to int
titanic['Sex'] = titanic['Sex'].astype(int)
titanic['Embarked'] = titanic['Embarked'].astype(int)

# %%
titanic.info()

# writing processed data to disk

# titanic.to_csv('preprocessed_titanic.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int32
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Embarked     891 non-null    int32
# dtypes: float64(2), int32(2), int64(5), object(1)
# memory usage: 62.8+ KB

# %%
# TODO: Should use bar plot to visualize this
plt.figure(figsize=(16, 6))
for i in range(1,4):
    Pclass_plot = titanic[titanic['Pclass']==i]
    plt.plot(Pclass_plot['Pclass'], Pclass_plot['Survived'], linestyle='none', marker='o', label=i)
plt.xlabel('Pclass')
plt.ylabel('Survived')
plt.legend()
# plt.plot(X_plot[:, 0], X_plot[:, 1], linestyle='none', marker='o', label=target_name)

# %%
_ = titanic.hist(figsize=(16,16), grid=False)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                               Heikkinen, Miss. Laina    1  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                             Allen, Mr. William Henry    0  35.000000      0
# ...
